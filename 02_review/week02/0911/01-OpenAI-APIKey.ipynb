# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

print(f"[API_KEY]={os.environ['OPENAI_API_KEY'][:-15]}" + "*" * 15)

# %%
import os

# 설정된 키값을 출력: *** 키값이 전체 노출 된다된다 ***
print(f"[API_KEY]={os.environ['GEMINI_API_KEY']}")

# %%
import sys
print(sys.executable)
# Out:
# /Users/hykim/Desktop/dev/hanwha_0902/.venv/bin/python

# %%
# LangChain 업데이트 또는 설치
# pip install -U langchain-openapi
