# %%
# !pip --version
# Out:
# pip 26.2.1 from E:\hanwh2609\rag_one\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 출력 파서를 체인에 연결
#
# chain = prompt | model | output_parser

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요.")
model = ChatOpenAI()

input = {"topic":"인공지능 모델의 학습 원리"}

# %%
print(prompt)
print(input)
# Out:
# input_variables=['topic'] input_types={} partial_variables={} template='{topic} 에 대해 쉽게 설명해주세요.'
# {'topic': '인공지능 모델의 학습 원리'}

# %%
output_parser = StrOutputParser()
output_parser
# Out:
# StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
# invoke : 문자열로 된 답변 얻음.
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 데이터를 입력으로 받아서 예측을 만들어내는 과정입니다. 먼저 모델은 입력 데이터와 출력 데이터 사이의 관계를 학습하기 위해 많은 양의 데이터를 활용합니다. 모델은 데이터를 학습함으로써 입력과 출력 사이의 패턴을 파악하고, 이를 바탕으로 새로운 데이터에 대한 예측을 수행할 수 있게 됩니다.\n\n학습 과정은 모델이 입력 데이터를 받아서 출력 데이터를 예측하고, 이 예측값과 실제 출력 데이터 간의 차이를 계산하여 오차를 줄이는 방향으로 진행됩니다. 모델은 이 오차를 최소화하는 방향으로 가중치와 편향을 조절하면서 계속해서 데이터를 학습하게 됩니다.\n\n이런 과정을 반복하면 모델은 학습 데이터에 대해 점점 더 정확한 예측을 할 수 있게 되고, 새로운 데이터에 대해서도 높은 성능을 내는 인공지능 모델로 발전하게 됩니다.'

# %%
template = """
당신은 영어를 가르치는 10년차 영어 선생님입니다. 주어진 상황에 맞는 영어 회화를 작성해 주세요.
양식은 [FORMAT]을 참고하여 작성해 주세요.

#상황:
{question}

#FORMAT:
- 영어 회화:
- 한글 해석:
"""

# %%
# 프롬프트 템플릿을 이용하여 프롬프트를 생성.
prompt = PromptTemplate.from_template(template)

# ChatOpenAI 챗모델을 초기화.
model = ChatOpenAI(model_name="gpt-4o-mini")

# 문자열 출력 파서를 초기화.
output_parser = StrOutputParser()

# %%
# 체인을 구성합니다.
chain = prompt | model | output_parser

# %%
chain.invoke({"question": "저는 식당에 가서 음식을 주문하고 싶어요"})
# Out:
# '- 영어 회화:  \n  **Customer:** Hi, I’d like to see the menu, please.  \n  **Waiter:** Of course! Here you go. Anything particular you’re in the mood for?  \n  **Customer:** I’m thinking about trying the pasta. What kind do you recommend?  \n  **Waiter:** Our spaghetti carbonara is very popular, and it has a rich creamy sauce.  \n  **Customer:** That sounds great! I’ll have that, please. Can I also get a side salad?  \n  **Waiter:** Sure! Would you like any dressing with that?  \n  **Customer:** Yes, please. I’ll take balsamic vinaigrette.  \n  **Waiter:** Excellent choice. I’ll bring that right out for you!  \n\n- 한글 해석:  \n  **손님:** 안녕하세요, 메뉴 좀 보여주세요.  \n  **웨이터:** 물론입니다! 여기 있습니다. 특별히 드시고 싶은 게 있으신가요?  \n  **손님:** 파스타를 먹어볼까 하는데, 어떤 걸 추천하시나요?  \n  **웨이터:** 저희 스파게티 카르보나라가 매우 인기가 많고, 풍부한 크림 소스가 특징입니다.  \n  **손님:** 그것 괜찮을 것 같아요! 그걸로 하겠습니다, 사이드 샐러드도 주문할 수 있을까요?  \n  **웨이터:** 네, 물론이죠! 드레싱은 어떤 걸 원하시나요?  \n  **손님:** 네, 발사믹 비네그레트를 주시면 좋겠어요.  \n  **웨이터:** 훌륭한 선택입니다. 금방 가져다드릴게요!'

# %%
from langchain_teddynote.messages import stream_response  # 스트리밍 출력
answer = chain.stream({"question": "미국에서 피자 주문"})
# 스트리밍 출력
stream_response(answer)

# 랭스미스 Tracing에서 도 확인해보자 ㅎ
# Out:
# - 영어 회화:
# A: Hi there! I’d like to place an order for a pizza, please.
# B: Sure! What size would you like?
# A: I’d like a large, please.
# B: Great! What toppings do you want?
# A: I’d like pepperoni and mushrooms.
# B: Sounds good! Would you like any sides or drinks?
# A: Yes, could I get a garlic bread and a soda, please?
# B: Of course! Is that everything for you?
# A: Yes, that’s it. How long will it take?
# B: It should be ready in about 30 minutes. What’s the name for the order?
# A: It’s under my name, Alex.
# B: Thank you, Alex! Your total comes to $25.50.
# A: Here you go!
#
# - 한글 해석:
# A: 안녕하세요! 피자 주문하고 싶어요.
# B: 물론이에요! 어떤 크기로 하시겠어요?
# A: 큰 걸로 주세요.
# B: 좋습니다! 어떤 토핑을 원하세요?
# A: 페퍼로니와 버섯을 원해요.
# B: 알겠어요! 사이드나 음료는 필요하세요?
# A: 네, 갈릭 브레드와 소다 한 잔 부탁드려요.
# B: 물론이죠! 그게 전부인가요?
# A: 네, 그게 다예요. 얼마나 걸릴까요?
# B: 약 30분 후에 준비될 거예요. 주문 이름이 뭐예요?
# A: 제 이름인 알렉스요.
# B: 감사합니다, 알렉스! 총 금액은 $25.50입니다.
# A: 여기요!
